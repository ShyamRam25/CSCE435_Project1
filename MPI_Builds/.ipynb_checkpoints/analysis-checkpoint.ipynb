# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

# %%
tk = th.Thicket.from_caliperreader("cali")
# Out:
# (1/2) Reading Files: 100%|██████████| 244/244 [00:15<00:00, 15.31it/s]
# (2/2) Creating Thicket: 100%|██████████| 243/243 [00:08<00:00, 28.14it/s]

# %%
df = tk.dataframe

# %%
comp_large_df = tk.dataframe[tk.dataframe['name'] == 'comp_large']
# print(comm_large_df)

comm_df = tk.dataframe[tk.dataframe['name'] == 'comm']
# print(comm_df)

main_df = tk.dataframe[tk.dataframe['name'] == 'main']
print(main_df)
# Out:
#                                                  nid   spot.channel  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077    1.0  regionprofile
#                                      30558843    1.0  regionprofile
#                                      53503295    1.0  regionprofile
#                                      82647496    1.0  regionprofile
#                                      88614086    1.0  regionprofile
# ...                                              ...            ...
#                                      4194353103  2.0  regionprofile
#                                      4197493351  2.0  regionprofile
#                                      4240018986  2.0  regionprofile
#                                      4268328121  2.0  regionprofile
#                                      4286169422  2.0  regionprofile
#
#                                                  Min time/rank  Max time/rank  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077        13.745552      13.778179
#                                      30558843        49.246398      49.246881
#                                      53503295         3.116484       3.129575
#                                      82647496         1.876371       1.887274
#                                      88614086        32.878873      32.886630
# ...                                                        ...            ...
#                                      4194353103       1.768562       1.785051
#                                      4197493351       0.615737       0.618698
#                                      4240018986      20.250048      20.533053
#                                      4268328121       4.049992       4.123165
#                                      4286169422       0.308206       0.308507
#
#                                                  Avg time/rank   Total time  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077        13.758843  7044.527446
#                                      30558843        49.246752   393.974019
#                                      53503295         3.123879   399.856574
#                                      82647496         1.881532    60.209020
#                                      88614086        32.882761  1052.248361
# ...                                                        ...          ...
#                                      4194353103       1.775962   454.646333
#                                      4197493351       0.617029     4.936235
#                                      4240018986      20.302826  1299.380854
#                                      4268328121       4.062196   259.980525
#                                      4286169422       0.308356     0.616713
#
#                                                  Variance time/rank  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077              0.000060
#                                      30558843              0.000000
#                                      53503295              0.000015
#                                      82647496              0.000016
#                                      88614086              0.000009
# ...                                                             ...
#                                      4194353103            0.000016
#                                      4197493351            0.000001
#                                      4240018986            0.001433
#                                      4268328121            0.000108
#                                      4286169422            0.000000
#
#                                                  Min time/rank (exc)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077               0.005402
#                                      30558843               0.005469
#                                      53503295               0.005410
#                                      82647496               0.005375
#                                      88614086               0.005472
# ...                                                              ...
#                                      4194353103             1.681125
#                                      4197493351             0.474686
#                                      4240018986             1.517650
#                                      4268328121             1.537999
#                                      4286169422             0.291670
#
#                                                  Max time/rank (exc)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077               0.012344
#                                      30558843               0.005577
#                                      53503295               0.005598
#                                      82647496               0.005529
#                                      88614086               0.005700
# ...                                                              ...
#                                      4194353103             1.751009
#                                      4197493351             0.481278
#                                      4240018986             1.608194
#                                      4268328121             1.551288
#                                      4286169422             0.296451
#
#                                                  Avg time/rank (exc)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077               0.005476
#                                      30558843               0.005506
#                                      53503295               0.005487
#                                      82647496               0.005439
#                                      88614086               0.005538
# ...                                                              ...
#                                      4194353103             1.709804
#                                      4197493351             0.476954
#                                      4240018986             1.580612
#                                      4268328121             1.544474
#                                      4286169422             0.294060
#
#                                                  Total time (exc)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077            2.803582
#                                      30558843            0.044052
#                                      53503295            0.702384
#                                      82647496            0.174058
#                                      88614086            0.177216
# ...                                                           ...
#                                      4194353103        437.709895
#                                      4197493351          3.815633
#                                      4240018986        101.159164
#                                      4268328121         98.846318
#                                      4286169422          0.588121
#
#                                                  Calls/rank (min)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077                 NaN
#                                      30558843                 NaN
#                                      53503295                 NaN
#                                      82647496                 NaN
#                                      88614086                 NaN
# ...                                                           ...
#                                      4194353103               1.0
#                                      4197493351               1.0
#                                      4240018986               1.0
#                                      4268328121               1.0
#                                      4286169422               1.0
#
#                                                  Calls/rank (avg)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077                 NaN
#                                      30558843                 NaN
#                                      53503295                 NaN
#                                      82647496                 NaN
#                                      88614086                 NaN
# ...                                                           ...
#                                      4194353103               1.0
#                                      4197493351               1.0
#                                      4240018986               1.0
#                                      4268328121               1.0
#                                      4286169422               1.0
#
#                                                  Calls/rank (max)  \
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077                 NaN
#                                      30558843                 NaN
#                                      53503295                 NaN
#                                      82647496                 NaN
#                                      88614086                 NaN
# ...                                                           ...
#                                      4194353103               1.0
#                                      4197493351               1.0
#                                      4240018986               1.0
#                                      4268328121               1.0
#                                      4286169422               1.0
#
#                                                  Calls/rank (total)  name
# node                                 profile
# {'name': 'main', 'type': 'function'} 27829077                   NaN  main
#                                      30558843                   NaN  main
#                                      53503295                   NaN  main
#                                      82647496                   NaN  main
#                                      88614086                   NaN  main
# ...                                                             ...   ...
#                                      4194353103               256.0  main
#                                      4197493351                 8.0  main
#                                      4240018986                64.0  main
#                                      4268328121                64.0  main
#                                      4286169422                 2.0  main
# [488 rows x 16 columns]

# %%
tk.show_metric_columns()
# Out:
# ['Total time',
#  'Calls/rank (max)',
#  'Avg time/rank (exc)',
#  'Avg time/rank',
#  'Min time/rank (exc)',
#  'Calls/rank (total)',
#  'Variance time/rank',
#  'Max time/rank',
#  'Total time (exc)',
#  'Max time/rank (exc)',
#  'Calls/rank (min)',
#  'Min time/rank',
#  'Calls/rank (avg)']

# %%
import colorama
colorama.init()

raw_output = tk.tree(metric_column = "Max time/rank")

import re
clean_output = re.sub(r'\x1b\[[0-9;]*m', '', raw_output)
print(clean_output)
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 13.778 main
# ├─ 0.894 MPI_Comm_dup
# ├─ 0.001 MPI_Finalize
# ├─ 0.000 MPI_Finalized
# ├─ 0.000 MPI_Initialized
# └─ 13.764 main
#    ├─ 0.000 MPI_Init
#    ├─ 0.995 comm
#    │  └─ 0.995 comm_large
#    │     ├─ 0.112 MPI_Gather
#    │     └─ 0.888 MPI_Scatter
#    ├─ 10.404 comp
#    │  └─ 10.404 comp_large
#    │     ├─ nan MPI_Barrier
#    │     ├─ nan comm
#    │     │  └─ nan comm_small
#    │     │     └─ nan MPI_Sendrecv
#    │     ├─ nan comp
#    │     │  ├─ nan comp_large
#    │     │  └─ nan comp_small
#    │     └─ 10.357 comp_small
#    │        ├─ 4.853 MPI_Barrier
#    │        └─ 9.917 comm_small
#    │           └─ 0.253 MPI_Sendrecv
#    ├─ 0.771 correctness_check
#    └─ 0.720 data_init_runtime
#
# Legend (Metric: Max time/rank Min: 0.00 Max: 13.78 indices: {'profile': 27829077})
# █ 12.40 - 13.78
# █ 9.64 - 12.40
# █ 6.89 - 9.64
# █ 4.13 - 6.89
# █ 1.38 - 4.13
# █ 0.00 - 1.38
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
metadata_df = tk.metadata

# %%
import pandas as pd

merged_df = metadata_df.merge(
    main_df[['Min time/rank', 'Max time/rank', 'Avg time/rank', 'Total time', 'Variance time/rank']],
    left_index=True,  # Use the index of metadata_df
    right_index=True,  # Use the index of comp_large_df
    how='inner'  # Keep only matching profiles
)


main_final_df = merged_df[['input_size', 'input_type', 'num_procs', 'Min time/rank', 'Max time/rank', 'Avg time/rank', 'Total time', 'Variance time/rank']]


# print(final_df)

# %%
# STRONG SCALING COMM_LARGE
import pandas as pd
import matplotlib.pyplot as plt


array_sizes = [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]

for array_size in array_sizes:

    filtered_df = main_final_df[final_df['input_size'] == array_size]


    colors = {
        'sorted': 'blue',
        'random': 'green',
        'reverse': 'orange',
        'perturbed': 'red'
    }


    plt.figure(figsize=(10, 8))

    
    for array_type, color in colors.items():
        type_data = filtered_df[filtered_df['input_type'] == array_type]

        type_data = type_data.sort_values('num_procs')

        plt.plot(type_data['num_procs'], type_data['Avg time/rank'], 
                 color=color, label=array_type, alpha=0.7, marker='o') 

    plt.title(f'Average Time vs Number of Processors for Array Size of {array_size}')
    plt.xlabel('Number of Processors')
    plt.ylabel('Average Time (seconds)')
    plt.xticks(filtered_df['num_procs'].unique())
    plt.grid()
    plt.legend(title='Array Type')
    plt.show()
# Out:
# /tmp/job.11794277/ipykernel_112217/95935436.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df = main_final_df[final_df['input_size'] == array_size]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In [27], line 10
#       6 array_sizes = [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]
#       8 for array_size in array_sizes:
# ---> 10     filtered_df = main_final_df[final_df['input_size'] == array_size]
#      13     colors = {
#      14         'sorted': 'blue',
#      15         'random': 'green',
#      16         'reverse': 'orange',
#      17         'perturbed': 'red'
#      18     }
#      21     plt.figure(figsize=(10, 8))
#
# File /scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages/pandas/core/frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages/pandas/core/frame.py:4149, in DataFrame._getitem_bool_array(self, key)
#    4143     raise ValueError(
#    4144         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    4145     )
#    4147 # check_bool_indexer will throw exception if Series key cannot
#    4148 # be reindexed to match DataFrame rows
# -> 4149 key = check_bool_indexer(self.index, key)
#    4151 if key.all():
#    4152     return self.copy(deep=None)
#
# File /scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages/pandas/core/indexing.py:2662, in check_bool_indexer(index, key)
#    2660 indexer = result.index.get_indexer_for(index)
#    2661 if -1 in indexer:
# -> 2662     raise IndexingError(
#    2663         "Unalignable boolean Series provided as "
#    2664         "indexer (index of the boolean Series and of "
#    2665         "the indexed object do not match)."
#    2666     )
#    2668 result = result.take(indexer)
#    2670 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
